# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
# !unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms
import torch.utils.data

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    transform = transforms.Compose([transforms.Resize(image_size),
                                   transforms.ToTensor()])
    image_dataset = datasets.ImageFolder(data_dir, transform)
    return torch.utils.data.DataLoader(image_dataset, batch_size = batch_size, shuffle = True)

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 128
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min, max = feature_range
    return x * (max - min) + min

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9294)
# Max:  tensor(0.9843)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
def conv(in_channels, out_channels, kernel_size, stride = 2, padding = 1, batch_norm = True):
    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels,
                          kernel_size, stride, padding, bias=False)
    layers.append(conv_layer)
    
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        self.Conv1 = conv(3,conv_dim,4,batch_norm=False)
        self.Conv2 = conv(conv_dim,conv_dim*2,4,batch_norm=True)
        self.Conv3 = conv(conv_dim*2,conv_dim*4,4,batch_norm=True)
        self.Conv4 = conv(conv_dim*4,conv_dim*8,4,batch_norm=True)
        self.Fc1 = nn.Linear(conv_dim*8*2*2,1)
        self.Dropout1 = nn.Dropout(0.2)
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        x = F.leaky_relu(self.Conv1(x),0.2)
        x = F.leaky_relu(self.Conv2(x),0.2)
        x = F.leaky_relu(self.Conv3(x),0.2)
        x = F.leaky_relu(self.Conv4(x),0.2)
        x = self.Dropout1(x)
        x = x.view(-1,self.conv_dim*8*2*2)
        x = self.Fc1(x)
        
        return x
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
def deconv(in_channels, out_channels, kernel_size, stride = 2, padding = 1, batch_norm = True):
    
    layers = []
    layers.append(nn.ConvTranspose2d(in_channels, out_channels,
                                   kernel_size, stride, padding, bias=False))
    
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        
        super(Generator, self).__init__()
              
        # complete init function
        self.conv_dim = conv_dim
        self.Fc2 = nn.Linear(z_size,conv_dim*8*2*2)
        self.Deconv1 = deconv(conv_dim*8,conv_dim*4,4,batch_norm=True)
        self.Deconv2 = deconv(conv_dim*4,conv_dim*2,4,batch_norm=True)
        self.Deconv3 = deconv(conv_dim*2,conv_dim,4,batch_norm=True)
        self.Deconv4 = deconv(conv_dim,3,4,batch_norm=False)
        self.Dropout2 = nn.Dropout(0.2)

          

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        x = self.Fc2(x)
        x = x.view(-1,self.conv_dim*8,2,2)
        x = F.relu(self.Deconv1(x))
        x = self.Dropout2(x)
        x = F.relu(self.Deconv2(x))
        x = self.Dropout2(x)
        x = F.relu(self.Deconv3(x))
        x = self.Dropout2(x)
        x = F.tanh(self.Deconv4(x))
        
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed
# /home/mina/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py:1558: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
from torch.nn import init
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    
    INIT_GAIN = 0.02
    
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear')!= -1):
    # TODO: Apply initial weights to convolutional and linear layers
            nn.init.normal_(m.weight.data, 0, INIT_GAIN)
            if hasattr(m, 'bias') and m.bias is not None:
                m.bias.data.zero_()                
    elif classname.find('BatchNorm2d') != -1:
        init.normal_(m.weight.data, 1.0, INIT_GAIN)
        init.constant_(m.bias.data, 0.0)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (Conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (Conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Fc1): Linear(in_features=1024, out_features=1, bias=True)
#   (Dropout1): Dropout(p=0.2, inplace=False)
# )
#
# Generator(
#   (Fc2): Linear(in_features=100, out_features=1024, bias=True)
#   (Deconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Deconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Deconv3): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Deconv4): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (Dropout2): Dropout(p=0.2, inplace=False)
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    
    labels = torch.ones(batch_size)
    
    if train_on_gpu:
        labels = labels.cuda()
    
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size)
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim
import torch
# Create optimizers for the discriminator D and generator G
lr = 0.001
optimizer1 = 0.5
optimizer2 = 0.999
d_optimizer = optim.Adam(D.parameters(), lr, [optimizer1, optimizer2])
g_optimizer = optim.Adam(D.parameters(), lr, [optimizer1, optimizer2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)
            
            if train_on_gpu:
                real_images = real_images.cuda()

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            d_optimizer.zero_grad()
            
            d_real_out = D(real_images)
            
            d_real_loss = real_loss(d_real_out)
            
            fake_images = G(fixed_z)
            
            d_fake_out = D(fake_images)
            
            d_fake_loss = fake_loss(d_fake_out)            
            
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            
            d_optimizer.step()
            

            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
            
            fake_images = G(fixed_z)
            
            g_out = D(fake_images)
            
            g_loss = real_loss(g_out)
            g_loss.backward()
            g_optimizer.step()
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 30


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   30] | d_loss: 1.6134 | g_loss: 1.5944
# Epoch [    1/   30] | d_loss: 1.3500 | g_loss: 0.7161
# Epoch [    1/   30] | d_loss: 1.3926 | g_loss: 0.5349
# Epoch [    1/   30] | d_loss: 1.1938 | g_loss: 0.6637
# Epoch [    1/   30] | d_loss: 1.1015 | g_loss: 0.6965
# Epoch [    1/   30] | d_loss: 1.2348 | g_loss: 0.6492
# Epoch [    1/   30] | d_loss: 1.2907 | g_loss: 0.6648
# Epoch [    1/   30] | d_loss: 1.0055 | g_loss: 0.6210
# Epoch [    1/   30] | d_loss: 1.1933 | g_loss: 0.6360
# Epoch [    1/   30] | d_loss: 1.1684 | g_loss: 0.5864
# Epoch [    1/   30] | d_loss: 1.1456 | g_loss: 0.5023
# Epoch [    1/   30] | d_loss: 1.2142 | g_loss: 0.6331
# Epoch [    1/   30] | d_loss: 1.0693 | g_loss: 0.6024
# Epoch [    1/   30] | d_loss: 1.0328 | g_loss: 0.5461
# Epoch [    1/   30] | d_loss: 1.4775 | g_loss: 0.8840
# Epoch [    2/   30] | d_loss: 0.9112 | g_loss: 0.6951
# Epoch [    2/   30] | d_loss: 1.2256 | g_loss: 0.8423
# Epoch [    2/   30] | d_loss: 1.0724 | g_loss: 0.5777
# Epoch [    2/   30] | d_loss: 1.1761 | g_loss: 0.5468
# Epoch [    2/   30] | d_loss: 1.0112 | g_loss: 0.6653
# Epoch [    2/   30] | d_loss: 1.3072 | g_loss: 0.5802
# Epoch [    2/   30] | d_loss: 1.0382 | g_loss: 0.5551
# Epoch [    2/   30] | d_loss: 1.3299 | g_loss: 0.6844
# Epoch [    2/   30] | d_loss: 1.1621 | g_loss: 0.5574
# Epoch [    2/   30] | d_loss: 0.7954 | g_loss: 0.6522
# Epoch [    2/   30] | d_loss: 1.0268 | g_loss: 0.5975
# Epoch [    2/   30] | d_loss: 1.2147 | g_loss: 0.6768
# Epoch [    2/   30] | d_loss: 0.9861 | g_loss: 0.6055
# Epoch [    2/   30] | d_loss: 1.0890 | g_loss: 0.5293
# Epoch [    2/   30] | d_loss: 1.0040 | g_loss: 0.5824
# Epoch [    3/   30] | d_loss: 0.9179 | g_loss: 0.6719
# Epoch [    3/   30] | d_loss: 0.8582 | g_loss: 0.6160
# Epoch [    3/   30] | d_loss: 1.2648 | g_loss: 0.7555
# Epoch [    3/   30] | d_loss: 1.0019 | g_loss: 0.4904
# Epoch [    3/   30] | d_loss: 1.1777 | g_loss: 0.5502
# Epoch [    3/   30] | d_loss: 0.9693 | g_loss: 0.6588
# Epoch [    3/   30] | d_loss: 1.0743 | g_loss: 0.4993
# Epoch [    3/   30] | d_loss: 1.1466 | g_loss: 0.6164
# Epoch [    3/   30] | d_loss: 0.9272 | g_loss: 0.6171
# Epoch [    3/   30] | d_loss: 1.1085 | g_loss: 0.5593
# Epoch [    3/   30] | d_loss: 1.1900 | g_loss: 0.5352
# Epoch [    3/   30] | d_loss: 1.0368 | g_loss: 0.5686
# Epoch [    3/   30] | d_loss: 1.0022 | g_loss: 0.5559
# Epoch [    3/   30] | d_loss: 1.1393 | g_loss: 0.6447
# Epoch [    3/   30] | d_loss: 1.0996 | g_loss: 0.7214
# Epoch [    4/   30] | d_loss: 1.1046 | g_loss: 0.5752
# Epoch [    4/   30] | d_loss: 0.8282 | g_loss: 0.5234
# Epoch [    4/   30] | d_loss: 1.0557 | g_loss: 0.6261
# Epoch [    4/   30] | d_loss: 0.9285 | g_loss: 0.6539
# Epoch [    4/   30] | d_loss: 0.9247 | g_loss: 0.5164
# Epoch [    4/   30] | d_loss: 0.9551 | g_loss: 0.5926
# Epoch [    4/   30] | d_loss: 0.9504 | g_loss: 0.5493
# Epoch [    4/   30] | d_loss: 1.0319 | g_loss: 0.7285
# Epoch [    4/   30] | d_loss: 1.0182 | g_loss: 0.5361
# Epoch [    4/   30] | d_loss: 0.9827 | g_loss: 0.4863
# Epoch [    4/   30] | d_loss: 1.0008 | g_loss: 0.5295
# Epoch [    4/   30] | d_loss: 0.9866 | g_loss: 0.5722
# Epoch [    4/   30] | d_loss: 1.0359 | g_loss: 0.5112
# Epoch [    4/   30] | d_loss: 1.2320 | g_loss: 0.5828
# Epoch [    4/   30] | d_loss: 0.8634 | g_loss: 0.6170
# Epoch [    5/   30] | d_loss: 0.8357 | g_loss: 0.6269
# Epoch [    5/   30] | d_loss: 0.8346 | g_loss: 0.5178
# Epoch [    5/   30] | d_loss: 0.8468 | g_loss: 0.5616
# Epoch [    5/   30] | d_loss: 0.9512 | g_loss: 0.5280
# Epoch [    5/   30] | d_loss: 1.1564 | g_loss: 0.6590
# Epoch [    5/   30] | d_loss: 0.7597 | g_loss: 0.6403
# Epoch [    5/   30] | d_loss: 1.0654 | g_loss: 0.6206
# Epoch [    5/   30] | d_loss: 1.1873 | g_loss: 0.5672
# Epoch [    5/   30] | d_loss: 0.9704 | g_loss: 0.5525
# Epoch [    5/   30] | d_loss: 0.9770 | g_loss: 0.5143
# Epoch [    5/   30] | d_loss: 0.8653 | g_loss: 0.5307
# Epoch [    5/   30] | d_loss: 0.8454 | g_loss: 0.6735
# Epoch [    5/   30] | d_loss: 0.8970 | g_loss: 0.6545
# Epoch [    5/   30] | d_loss: 1.0644 | g_loss: 0.8583
# Epoch [    5/   30] | d_loss: 0.9637 | g_loss: 0.5734
# Epoch [    6/   30] | d_loss: 1.0584 | g_loss: 0.5399
# Epoch [    6/   30] | d_loss: 0.9865 | g_loss: 0.6039
# Epoch [    6/   30] | d_loss: 0.8696 | g_loss: 0.5453
# Epoch [    6/   30] | d_loss: 0.9769 | g_loss: 0.5682
# Epoch [    6/   30] | d_loss: 0.9075 | g_loss: 0.5804
# Epoch [    6/   30] | d_loss: 1.1190 | g_loss: 0.6468
# Epoch [    6/   30] | d_loss: 0.8435 | g_loss: 0.6429
# Epoch [    6/   30] | d_loss: 1.1175 | g_loss: 0.6467
# Epoch [    6/   30] | d_loss: 0.8803 | g_loss: 0.7003
# Epoch [    6/   30] | d_loss: 1.0404 | g_loss: 0.6322
# Epoch [    6/   30] | d_loss: 0.8813 | g_loss: 0.6084
# Epoch [    6/   30] | d_loss: 0.8314 | g_loss: 0.7150
# Epoch [    6/   30] | d_loss: 0.9751 | g_loss: 0.5966
# Epoch [    6/   30] | d_loss: 0.9517 | g_loss: 0.7274
# Epoch [    6/   30] | d_loss: 0.9880 | g_loss: 0.6202
# Epoch [    7/   30] | d_loss: 0.9396 | g_loss: 0.5756
# Epoch [    7/   30] | d_loss: 0.9048 | g_loss: 0.6945
# Epoch [    7/   30] | d_loss: 0.9167 | g_loss: 0.5433
# Epoch [    7/   30] | d_loss: 0.9155 | g_loss: 0.5707
# Epoch [    7/   30] | d_loss: 0.9111 | g_loss: 0.5856
# Epoch [    7/   30] | d_loss: 1.0354 | g_loss: 0.5592
# Epoch [    7/   30] | d_loss: 0.9600 | g_loss: 0.5683
# Epoch [    7/   30] | d_loss: 0.9154 | g_loss: 0.5262
# Epoch [    7/   30] | d_loss: 0.9407 | g_loss: 0.5409
# Epoch [    7/   30] | d_loss: 0.8312 | g_loss: 0.5987
# Epoch [    7/   30] | d_loss: 0.8638 | g_loss: 0.5994
# Epoch [    7/   30] | d_loss: 0.8011 | g_loss: 0.5466
# Epoch [    7/   30] | d_loss: 0.9982 | g_loss: 0.6227
# Epoch [    7/   30] | d_loss: 1.0522 | g_loss: 0.5826
# Epoch [    7/   30] | d_loss: 0.8437 | g_loss: 0.6906
# Epoch [    8/   30] | d_loss: 1.2325 | g_loss: 0.5781
# Epoch [    8/   30] | d_loss: 0.9125 | g_loss: 0.6379
# Epoch [    8/   30] | d_loss: 0.8593 | g_loss: 0.5990
# Epoch [    8/   30] | d_loss: 0.9186 | g_loss: 0.6300
# Epoch [    8/   30] | d_loss: 0.8003 | g_loss: 0.5898
# Epoch [    8/   30] | d_loss: 0.8266 | g_loss: 0.6501
# Epoch [    8/   30] | d_loss: 0.8562 | g_loss: 0.7236
# Epoch [    8/   30] | d_loss: 0.9511 | g_loss: 0.6044
# Epoch [    8/   30] | d_loss: 0.9089 | g_loss: 0.5750
# Epoch [    8/   30] | d_loss: 0.8644 | g_loss: 0.6511
# Epoch [    8/   30] | d_loss: 0.9598 | g_loss: 0.5449
# Epoch [    8/   30] | d_loss: 0.8027 | g_loss: 0.6879
# Epoch [    8/   30] | d_loss: 0.9804 | g_loss: 0.5874
# Epoch [    8/   30] | d_loss: 0.9250 | g_loss: 0.6541
# Epoch [    8/   30] | d_loss: 0.8686 | g_loss: 0.6073
# Epoch [    9/   30] | d_loss: 0.8790 | g_loss: 0.6340
# Epoch [    9/   30] | d_loss: 0.9168 | g_loss: 0.5876
# Epoch [    9/   30] | d_loss: 0.9959 | g_loss: 0.5429
# Epoch [    9/   30] | d_loss: 0.8845 | g_loss: 0.6001
# Epoch [    9/   30] | d_loss: 0.8220 | g_loss: 0.5864
# Epoch [    9/   30] | d_loss: 0.9140 | g_loss: 0.6140
# Epoch [    9/   30] | d_loss: 0.8841 | g_loss: 0.6763
# Epoch [    9/   30] | d_loss: 0.8933 | g_loss: 0.6517
# Epoch [    9/   30] | d_loss: 0.9142 | g_loss: 0.7413
# Epoch [    9/   30] | d_loss: 0.8850 | g_loss: 0.6635
# Epoch [    9/   30] | d_loss: 0.8385 | g_loss: 0.6117
# Epoch [    9/   30] | d_loss: 0.8158 | g_loss: 0.5969
# Epoch [    9/   30] | d_loss: 0.9592 | g_loss: 0.5468
# Epoch [    9/   30] | d_loss: 1.0663 | g_loss: 0.6576
# Epoch [    9/   30] | d_loss: 0.8946 | g_loss: 0.5655
# Epoch [   10/   30] | d_loss: 0.9795 | g_loss: 0.6053
# Epoch [   10/   30] | d_loss: 0.9257 | g_loss: 0.6035
# Epoch [   10/   30] | d_loss: 0.9275 | g_loss: 0.6611
# Epoch [   10/   30] | d_loss: 0.9330 | g_loss: 0.6279
# Epoch [   10/   30] | d_loss: 0.8800 | g_loss: 0.6028
# Epoch [   10/   30] | d_loss: 0.8513 | g_loss: 0.6431
# Epoch [   10/   30] | d_loss: 0.9566 | g_loss: 0.6123
# Epoch [   10/   30] | d_loss: 0.8831 | g_loss: 0.6149
# Epoch [   10/   30] | d_loss: 0.8087 | g_loss: 0.6255
# Epoch [   10/   30] | d_loss: 0.8803 | g_loss: 0.6745
# Epoch [   10/   30] | d_loss: 1.0025 | g_loss: 0.5601
# Epoch [   10/   30] | d_loss: 0.7813 | g_loss: 0.6405
# Epoch [   10/   30] | d_loss: 0.9191 | g_loss: 0.5820
# Epoch [   10/   30] | d_loss: 0.8817 | g_loss: 0.6554
# Epoch [   10/   30] | d_loss: 0.8635 | g_loss: 0.6354
# Epoch [   11/   30] | d_loss: 0.9159 | g_loss: 0.6889
# Epoch [   11/   30] | d_loss: 0.9659 | g_loss: 0.6603
# Epoch [   11/   30] | d_loss: 0.9064 | g_loss: 0.5658
# Epoch [   11/   30] | d_loss: 0.8323 | g_loss: 0.6335
# Epoch [   11/   30] | d_loss: 0.8086 | g_loss: 0.7140
# Epoch [   11/   30] | d_loss: 0.8357 | g_loss: 0.6746
# Epoch [   11/   30] | d_loss: 0.8558 | g_loss: 0.6297
# Epoch [   11/   30] | d_loss: 0.9004 | g_loss: 0.6455
# Epoch [   11/   30] | d_loss: 0.8276 | g_loss: 0.6600
# Epoch [   11/   30] | d_loss: 0.8519 | g_loss: 0.5994
# Epoch [   11/   30] | d_loss: 0.9416 | g_loss: 0.7519
# Epoch [   11/   30] | d_loss: 0.8880 | g_loss: 0.6227
# Epoch [   11/   30] | d_loss: 0.8250 | g_loss: 0.5749
# Epoch [   11/   30] | d_loss: 0.8005 | g_loss: 0.6724
# Epoch [   11/   30] | d_loss: 1.0089 | g_loss: 0.5639
# Epoch [   12/   30] | d_loss: 0.9139 | g_loss: 0.7197
# Epoch [   12/   30] | d_loss: 0.9235 | g_loss: 0.5872
# Epoch [   12/   30] | d_loss: 0.9556 | g_loss: 0.5868
# Epoch [   12/   30] | d_loss: 0.8921 | g_loss: 0.5995
# Epoch [   12/   30] | d_loss: 0.9619 | g_loss: 0.7249
# Epoch [   12/   30] | d_loss: 0.9480 | g_loss: 0.6391
# Epoch [   12/   30] | d_loss: 0.9133 | g_loss: 0.6309
# Epoch [   12/   30] | d_loss: 0.8938 | g_loss: 0.5879
# Epoch [   12/   30] | d_loss: 0.7901 | g_loss: 0.6690
# Epoch [   12/   30] | d_loss: 0.9069 | g_loss: 0.6623
# Epoch [   12/   30] | d_loss: 0.7607 | g_loss: 0.7822
# Epoch [   12/   30] | d_loss: 0.8254 | g_loss: 0.6746
# Epoch [   12/   30] | d_loss: 1.0954 | g_loss: 0.7929
# Epoch [   12/   30] | d_loss: 0.7899 | g_loss: 0.6407
# Epoch [   12/   30] | d_loss: 0.9393 | g_loss: 0.6799
# Epoch [   13/   30] | d_loss: 0.8178 | g_loss: 0.6276
# Epoch [   13/   30] | d_loss: 0.9233 | g_loss: 0.5729
# Epoch [   13/   30] | d_loss: 0.8480 | g_loss: 0.5619
# Epoch [   13/   30] | d_loss: 0.9044 | g_loss: 0.6737
# Epoch [   13/   30] | d_loss: 1.0255 | g_loss: 0.6274
# Epoch [   13/   30] | d_loss: 0.8841 | g_loss: 0.6285
# Epoch [   13/   30] | d_loss: 0.9131 | g_loss: 0.6042
# Epoch [   13/   30] | d_loss: 0.7679 | g_loss: 0.6126
# Epoch [   13/   30] | d_loss: 0.8845 | g_loss: 0.6365
# Epoch [   13/   30] | d_loss: 1.1003 | g_loss: 0.6602
# Epoch [   13/   30] | d_loss: 0.7795 | g_loss: 0.6679
# Epoch [   13/   30] | d_loss: 0.8837 | g_loss: 0.6616
# Epoch [   13/   30] | d_loss: 0.9845 | g_loss: 0.6061
# Epoch [   13/   30] | d_loss: 0.8417 | g_loss: 0.6597
# Epoch [   13/   30] | d_loss: 0.9016 | g_loss: 0.6400
# Epoch [   14/   30] | d_loss: 0.9875 | g_loss: 0.6706
# Epoch [   14/   30] | d_loss: 0.8594 | g_loss: 0.7842
# Epoch [   14/   30] | d_loss: 0.8124 | g_loss: 0.5920
# Epoch [   14/   30] | d_loss: 0.9865 | g_loss: 0.5856
# Epoch [   14/   30] | d_loss: 0.9382 | g_loss: 0.6369
# Epoch [   14/   30] | d_loss: 0.8621 | g_loss: 0.5984
# Epoch [   14/   30] | d_loss: 0.8507 | g_loss: 0.7772
# Epoch [   14/   30] | d_loss: 0.9521 | g_loss: 0.6456
# Epoch [   14/   30] | d_loss: 0.7665 | g_loss: 0.5943
# Epoch [   14/   30] | d_loss: 0.8541 | g_loss: 0.5261
# Epoch [   14/   30] | d_loss: 0.8169 | g_loss: 0.6936
# Epoch [   14/   30] | d_loss: 0.9485 | g_loss: 0.7131
# Epoch [   14/   30] | d_loss: 1.0247 | g_loss: 0.6486
# Epoch [   14/   30] | d_loss: 0.9519 | g_loss: 0.6390
# Epoch [   14/   30] | d_loss: 0.8412 | g_loss: 0.8183
# Epoch [   15/   30] | d_loss: 0.8103 | g_loss: 0.8128
# Epoch [   15/   30] | d_loss: 1.0144 | g_loss: 0.6307
# Epoch [   15/   30] | d_loss: 0.8489 | g_loss: 0.6212
# Epoch [   15/   30] | d_loss: 0.8515 | g_loss: 0.9085
# Epoch [   15/   30] | d_loss: 0.8267 | g_loss: 0.6705
# Epoch [   15/   30] | d_loss: 0.9163 | g_loss: 0.6221
# Epoch [   15/   30] | d_loss: 0.9333 | g_loss: 0.7014
# Epoch [   15/   30] | d_loss: 0.8957 | g_loss: 0.5816
# Epoch [   15/   30] | d_loss: 0.9332 | g_loss: 0.7121
# Epoch [   15/   30] | d_loss: 0.8944 | g_loss: 0.6943
# Epoch [   15/   30] | d_loss: 0.8574 | g_loss: 0.5881
# Epoch [   15/   30] | d_loss: 0.7999 | g_loss: 0.5328
# Epoch [   15/   30] | d_loss: 0.9593 | g_loss: 0.5878
# Epoch [   15/   30] | d_loss: 0.8582 | g_loss: 0.6458
# Epoch [   15/   30] | d_loss: 0.8708 | g_loss: 0.6975
# Epoch [   16/   30] | d_loss: 0.8520 | g_loss: 0.6494
# Epoch [   16/   30] | d_loss: 0.7824 | g_loss: 0.7043
# Epoch [   16/   30] | d_loss: 0.8538 | g_loss: 0.8180
# Epoch [   16/   30] | d_loss: 0.8211 | g_loss: 0.6644
# Epoch [   16/   30] | d_loss: 0.8619 | g_loss: 0.5542
# Epoch [   16/   30] | d_loss: 0.8404 | g_loss: 0.5125
# Epoch [   16/   30] | d_loss: 0.9118 | g_loss: 0.6829
# Epoch [   16/   30] | d_loss: 0.9444 | g_loss: 0.6464
# Epoch [   16/   30] | d_loss: 0.7648 | g_loss: 0.5616
# Epoch [   16/   30] | d_loss: 0.8001 | g_loss: 0.6953
# Epoch [   16/   30] | d_loss: 0.9429 | g_loss: 0.7423
# Epoch [   16/   30] | d_loss: 0.7483 | g_loss: 0.6191
# Epoch [   16/   30] | d_loss: 1.0661 | g_loss: 0.6524
# Epoch [   16/   30] | d_loss: 0.8744 | g_loss: 0.7246
# Epoch [   16/   30] | d_loss: 0.8288 | g_loss: 0.7303
# Epoch [   17/   30] | d_loss: 0.7834 | g_loss: 0.6749
# Epoch [   17/   30] | d_loss: 0.9067 | g_loss: 0.6465
# Epoch [   17/   30] | d_loss: 0.8530 | g_loss: 0.6037
# Epoch [   17/   30] | d_loss: 0.8688 | g_loss: 0.6185
# Epoch [   17/   30] | d_loss: 0.8204 | g_loss: 0.8328
# Epoch [   17/   30] | d_loss: 0.8428 | g_loss: 0.6210
# Epoch [   17/   30] | d_loss: 0.7967 | g_loss: 0.6331
# Epoch [   17/   30] | d_loss: 0.7776 | g_loss: 0.7140
# Epoch [   17/   30] | d_loss: 0.9568 | g_loss: 0.5679
# Epoch [   17/   30] | d_loss: 0.7467 | g_loss: 0.6449
# Epoch [   17/   30] | d_loss: 0.7764 | g_loss: 0.6593
# Epoch [   17/   30] | d_loss: 0.9253 | g_loss: 0.7148
# Epoch [   17/   30] | d_loss: 0.9559 | g_loss: 0.7929
# Epoch [   17/   30] | d_loss: 0.8805 | g_loss: 0.7359
# Epoch [   17/   30] | d_loss: 0.9851 | g_loss: 0.6870
# Epoch [   18/   30] | d_loss: 0.8102 | g_loss: 0.6142
# Epoch [   18/   30] | d_loss: 1.0419 | g_loss: 0.8214
# Epoch [   18/   30] | d_loss: 0.8325 | g_loss: 0.7990
# Epoch [   18/   30] | d_loss: 0.9532 | g_loss: 0.7130
# Epoch [   18/   30] | d_loss: 0.9607 | g_loss: 0.8155
# Epoch [   18/   30] | d_loss: 0.8999 | g_loss: 0.6509
# Epoch [   18/   30] | d_loss: 0.9127 | g_loss: 0.6417
# Epoch [   18/   30] | d_loss: 0.9045 | g_loss: 0.8668
# Epoch [   18/   30] | d_loss: 0.8578 | g_loss: 0.7027
# Epoch [   18/   30] | d_loss: 0.8682 | g_loss: 0.5934
# Epoch [   18/   30] | d_loss: 0.7478 | g_loss: 0.7983
# Epoch [   18/   30] | d_loss: 0.8803 | g_loss: 0.7716
# Epoch [   18/   30] | d_loss: 0.7868 | g_loss: 0.5375
# Epoch [   18/   30] | d_loss: 0.7721 | g_loss: 0.8148
# Epoch [   18/   30] | d_loss: 0.9896 | g_loss: 0.6421
# Epoch [   19/   30] | d_loss: 0.8009 | g_loss: 0.5815
# Epoch [   19/   30] | d_loss: 0.8167 | g_loss: 0.7788
# Epoch [   19/   30] | d_loss: 0.8850 | g_loss: 0.5826
# Epoch [   19/   30] | d_loss: 0.9313 | g_loss: 0.6638
# Epoch [   19/   30] | d_loss: 0.8001 | g_loss: 0.6819
# Epoch [   19/   30] | d_loss: 1.0021 | g_loss: 0.6556
# Epoch [   19/   30] | d_loss: 0.8782 | g_loss: 0.6813
# Epoch [   19/   30] | d_loss: 0.8373 | g_loss: 0.7199
# Epoch [   19/   30] | d_loss: 0.8293 | g_loss: 0.6381
# Epoch [   19/   30] | d_loss: 0.9244 | g_loss: 0.6861
# Epoch [   19/   30] | d_loss: 0.7525 | g_loss: 0.7085
# Epoch [   19/   30] | d_loss: 0.8035 | g_loss: 0.5716
# Epoch [   19/   30] | d_loss: 0.8092 | g_loss: 0.7052
# Epoch [   19/   30] | d_loss: 0.8564 | g_loss: 0.7182
# Epoch [   19/   30] | d_loss: 0.9412 | g_loss: 0.9536
# Epoch [   20/   30] | d_loss: 0.9083 | g_loss: 0.7030
# Epoch [   20/   30] | d_loss: 0.8833 | g_loss: 0.5867
# Epoch [   20/   30] | d_loss: 0.8003 | g_loss: 0.7158
# Epoch [   20/   30] | d_loss: 0.7092 | g_loss: 0.6251
# Epoch [   20/   30] | d_loss: 0.9128 | g_loss: 0.7586
# Epoch [   20/   30] | d_loss: 0.8699 | g_loss: 0.7350
# Epoch [   20/   30] | d_loss: 1.1150 | g_loss: 0.7265
# Epoch [   20/   30] | d_loss: 1.0109 | g_loss: 0.6599
# Epoch [   20/   30] | d_loss: 0.6818 | g_loss: 0.6730
# Epoch [   20/   30] | d_loss: 0.8280 | g_loss: 0.8718
# Epoch [   20/   30] | d_loss: 0.8223 | g_loss: 0.7099
# Epoch [   20/   30] | d_loss: 0.8054 | g_loss: 0.8074
# Epoch [   20/   30] | d_loss: 0.9021 | g_loss: 0.6213
# Epoch [   20/   30] | d_loss: 0.8717 | g_loss: 0.5846
# Epoch [   20/   30] | d_loss: 0.7585 | g_loss: 0.7426
# Epoch [   21/   30] | d_loss: 0.8326 | g_loss: 0.8278
# Epoch [   21/   30] | d_loss: 0.8231 | g_loss: 0.5433
# Epoch [   21/   30] | d_loss: 0.8484 | g_loss: 0.5959
# Epoch [   21/   30] | d_loss: 0.8404 | g_loss: 0.7144
# Epoch [   21/   30] | d_loss: 0.7530 | g_loss: 0.5230
# Epoch [   21/   30] | d_loss: 0.9136 | g_loss: 0.9136
# Epoch [   21/   30] | d_loss: 0.7683 | g_loss: 0.8729
# Epoch [   21/   30] | d_loss: 0.8094 | g_loss: 0.7083
# Epoch [   21/   30] | d_loss: 0.8069 | g_loss: 0.5859
# Epoch [   21/   30] | d_loss: 0.7174 | g_loss: 0.7188
# Epoch [   21/   30] | d_loss: 0.8856 | g_loss: 0.6783
# Epoch [   21/   30] | d_loss: 0.8601 | g_loss: 0.6880
# Epoch [   21/   30] | d_loss: 0.9511 | g_loss: 0.7723
# Epoch [   21/   30] | d_loss: 0.7524 | g_loss: 0.6470
# Epoch [   21/   30] | d_loss: 0.7462 | g_loss: 0.5751
# Epoch [   22/   30] | d_loss: 0.7479 | g_loss: 0.6505
# Epoch [   22/   30] | d_loss: 0.9693 | g_loss: 0.7366
# Epoch [   22/   30] | d_loss: 0.8756 | g_loss: 0.7162
# Epoch [   22/   30] | d_loss: 0.7852 | g_loss: 0.6921
# Epoch [   22/   30] | d_loss: 1.0325 | g_loss: 0.8905
# Epoch [   22/   30] | d_loss: 0.8136 | g_loss: 0.6133
# Epoch [   22/   30] | d_loss: 0.7578 | g_loss: 0.8434
# Epoch [   22/   30] | d_loss: 0.7244 | g_loss: 0.7907
# Epoch [   22/   30] | d_loss: 0.8660 | g_loss: 0.8604
# Epoch [   22/   30] | d_loss: 0.7655 | g_loss: 0.6367
# Epoch [   22/   30] | d_loss: 0.7460 | g_loss: 0.6206
# Epoch [   22/   30] | d_loss: 0.8189 | g_loss: 0.8312
# Epoch [   22/   30] | d_loss: 0.7436 | g_loss: 0.5113
# Epoch [   22/   30] | d_loss: 0.8559 | g_loss: 0.8276
# Epoch [   22/   30] | d_loss: 1.1009 | g_loss: 0.8062
# Epoch [   23/   30] | d_loss: 0.8383 | g_loss: 0.6660
# Epoch [   23/   30] | d_loss: 0.9141 | g_loss: 0.5550
# Epoch [   23/   30] | d_loss: 0.9539 | g_loss: 0.6321
# Epoch [   23/   30] | d_loss: 0.8198 | g_loss: 0.6349
# Epoch [   23/   30] | d_loss: 0.6787 | g_loss: 0.6732
# Epoch [   23/   30] | d_loss: 0.9611 | g_loss: 0.6661
# Epoch [   23/   30] | d_loss: 0.8941 | g_loss: 0.6157
# Epoch [   23/   30] | d_loss: 0.8681 | g_loss: 0.7134
# Epoch [   23/   30] | d_loss: 0.7892 | g_loss: 0.6152
# Epoch [   23/   30] | d_loss: 0.8169 | g_loss: 0.7636
# Epoch [   23/   30] | d_loss: 0.7123 | g_loss: 0.6472
# Epoch [   23/   30] | d_loss: 0.6381 | g_loss: 0.7895
# Epoch [   23/   30] | d_loss: 1.0290 | g_loss: 0.7114
# Epoch [   23/   30] | d_loss: 0.9646 | g_loss: 0.8139
# Epoch [   23/   30] | d_loss: 1.0447 | g_loss: 0.8633
# Epoch [   24/   30] | d_loss: 0.9137 | g_loss: 0.5666
# Epoch [   24/   30] | d_loss: 1.0709 | g_loss: 0.7478
# Epoch [   24/   30] | d_loss: 0.6028 | g_loss: 0.7622
# Epoch [   24/   30] | d_loss: 0.7891 | g_loss: 0.7199
# Epoch [   24/   30] | d_loss: 0.8977 | g_loss: 0.6559
# Epoch [   24/   30] | d_loss: 0.7699 | g_loss: 0.6332
# Epoch [   24/   30] | d_loss: 0.5478 | g_loss: 0.5273
# Epoch [   24/   30] | d_loss: 0.8413 | g_loss: 0.7581
# Epoch [   24/   30] | d_loss: 0.8685 | g_loss: 0.7166
# Epoch [   24/   30] | d_loss: 0.7984 | g_loss: 0.6065
# Epoch [   24/   30] | d_loss: 0.7334 | g_loss: 0.7518
# Epoch [   24/   30] | d_loss: 0.7099 | g_loss: 0.4923
# Epoch [   24/   30] | d_loss: 0.8614 | g_loss: 0.8229
# Epoch [   24/   30] | d_loss: 0.8746 | g_loss: 0.8297
# Epoch [   24/   30] | d_loss: 0.8307 | g_loss: 0.6955
# Epoch [   25/   30] | d_loss: 0.6327 | g_loss: 0.6285
# Epoch [   25/   30] | d_loss: 0.7849 | g_loss: 0.6547
# Epoch [   25/   30] | d_loss: 1.1221 | g_loss: 0.6312
# Epoch [   25/   30] | d_loss: 0.8364 | g_loss: 0.7576
# Epoch [   25/   30] | d_loss: 0.6595 | g_loss: 0.6527
# Epoch [   25/   30] | d_loss: 0.9133 | g_loss: 0.5023
# Epoch [   25/   30] | d_loss: 0.7007 | g_loss: 0.7203
# Epoch [   25/   30] | d_loss: 0.7524 | g_loss: 0.7381
# Epoch [   25/   30] | d_loss: 0.7897 | g_loss: 0.8027
# Epoch [   25/   30] | d_loss: 0.6815 | g_loss: 0.7787
# Epoch [   25/   30] | d_loss: 0.7290 | g_loss: 0.7876
# Epoch [   25/   30] | d_loss: 0.6365 | g_loss: 0.6965
# Epoch [   25/   30] | d_loss: 0.8461 | g_loss: 0.7689
# Epoch [   25/   30] | d_loss: 0.8028 | g_loss: 1.0824
# Epoch [   25/   30] | d_loss: 0.8553 | g_loss: 0.9047
# Epoch [   26/   30] | d_loss: 0.7038 | g_loss: 0.7940
# Epoch [   26/   30] | d_loss: 0.8367 | g_loss: 0.8556
# Epoch [   26/   30] | d_loss: 0.7765 | g_loss: 0.8078
# Epoch [   26/   30] | d_loss: 0.9852 | g_loss: 0.8330
# Epoch [   26/   30] | d_loss: 0.9378 | g_loss: 0.7823
# Epoch [   26/   30] | d_loss: 0.7313 | g_loss: 0.7663
# Epoch [   26/   30] | d_loss: 0.9644 | g_loss: 0.5878
# Epoch [   26/   30] | d_loss: 0.7722 | g_loss: 0.8052
# Epoch [   26/   30] | d_loss: 0.9085 | g_loss: 0.6548
# Epoch [   26/   30] | d_loss: 0.9524 | g_loss: 0.6605
# Epoch [   26/   30] | d_loss: 0.6262 | g_loss: 0.5878
# Epoch [   26/   30] | d_loss: 0.7943 | g_loss: 0.9274
# Epoch [   26/   30] | d_loss: 0.9516 | g_loss: 0.5758
# Epoch [   26/   30] | d_loss: 0.8240 | g_loss: 0.7213
# Epoch [   26/   30] | d_loss: 0.9222 | g_loss: 0.7024
# Epoch [   27/   30] | d_loss: 0.9064 | g_loss: 0.6508
# Epoch [   27/   30] | d_loss: 0.9294 | g_loss: 0.8367
# Epoch [   27/   30] | d_loss: 0.7708 | g_loss: 0.7523
# Epoch [   27/   30] | d_loss: 0.8047 | g_loss: 0.8968
# Epoch [   27/   30] | d_loss: 0.8211 | g_loss: 0.7971
# Epoch [   27/   30] | d_loss: 0.9715 | g_loss: 0.6755
# Epoch [   27/   30] | d_loss: 0.7339 | g_loss: 0.7490
# Epoch [   27/   30] | d_loss: 0.6648 | g_loss: 0.9353
# Epoch [   27/   30] | d_loss: 0.9694 | g_loss: 0.7813
# Epoch [   27/   30] | d_loss: 0.8298 | g_loss: 1.1900
# Epoch [   27/   30] | d_loss: 0.7926 | g_loss: 0.8316
# Epoch [   27/   30] | d_loss: 0.8696 | g_loss: 0.6038
# Epoch [   27/   30] | d_loss: 0.9485 | g_loss: 0.7274
# Epoch [   27/   30] | d_loss: 0.8240 | g_loss: 0.8166
# Epoch [   27/   30] | d_loss: 1.1713 | g_loss: 0.9742
# Epoch [   28/   30] | d_loss: 0.9256 | g_loss: 0.6894
# Epoch [   28/   30] | d_loss: 0.8010 | g_loss: 0.6241
# Epoch [   28/   30] | d_loss: 0.8109 | g_loss: 1.2455
# Epoch [   28/   30] | d_loss: 0.7545 | g_loss: 0.8087
# Epoch [   28/   30] | d_loss: 0.8103 | g_loss: 1.0183
# Epoch [   28/   30] | d_loss: 0.7866 | g_loss: 0.6830
# Epoch [   28/   30] | d_loss: 0.7547 | g_loss: 0.6583
# Epoch [   28/   30] | d_loss: 0.7415 | g_loss: 0.6839
# Epoch [   28/   30] | d_loss: 0.8619 | g_loss: 0.6583
# Epoch [   28/   30] | d_loss: 0.7581 | g_loss: 0.7210
# Epoch [   28/   30] | d_loss: 0.8699 | g_loss: 0.7525
# Epoch [   28/   30] | d_loss: 0.8242 | g_loss: 0.7980
# Epoch [   28/   30] | d_loss: 1.1020 | g_loss: 0.8954
# Epoch [   28/   30] | d_loss: 0.8712 | g_loss: 0.6451
# Epoch [   28/   30] | d_loss: 0.4815 | g_loss: 0.6532
# Epoch [   29/   30] | d_loss: 0.8167 | g_loss: 0.7392
# Epoch [   29/   30] | d_loss: 0.9548 | g_loss: 0.8676
# Epoch [   29/   30] | d_loss: 0.8741 | g_loss: 0.5790
# Epoch [   29/   30] | d_loss: 0.7236 | g_loss: 0.5886
# Epoch [   29/   30] | d_loss: 0.6456 | g_loss: 0.7853
# Epoch [   29/   30] | d_loss: 0.9041 | g_loss: 0.7659
# Epoch [   29/   30] | d_loss: 0.8792 | g_loss: 0.8584
# Epoch [   29/   30] | d_loss: 0.7713 | g_loss: 0.6503
# Epoch [   29/   30] | d_loss: 0.7518 | g_loss: 0.9114
# Epoch [   29/   30] | d_loss: 0.9314 | g_loss: 0.6993
# Epoch [   29/   30] | d_loss: 0.7409 | g_loss: 0.7672
# Epoch [   29/   30] | d_loss: 0.8387 | g_loss: 0.7820
# Epoch [   29/   30] | d_loss: 0.6126 | g_loss: 0.7332
# Epoch [   29/   30] | d_loss: 0.8505 | g_loss: 0.6620
# Epoch [   29/   30] | d_loss: 0.9827 | g_loss: 0.9633
# Epoch [   30/   30] | d_loss: 0.9900 | g_loss: 0.7465
# Epoch [   30/   30] | d_loss: 0.7113 | g_loss: 0.7966
# Epoch [   30/   30] | d_loss: 0.7143 | g_loss: 0.6250
# Epoch [   30/   30] | d_loss: 0.8781 | g_loss: 0.8444
# Epoch [   30/   30] | d_loss: 0.6934 | g_loss: 0.9093
# Epoch [   30/   30] | d_loss: 0.7897 | g_loss: 0.8415
# Epoch [   30/   30] | d_loss: 0.9420 | g_loss: 0.8404
# Epoch [   30/   30] | d_loss: 0.9036 | g_loss: 0.8618
# Epoch [   30/   30] | d_loss: 0.7597 | g_loss: 0.6849
# Epoch [   30/   30] | d_loss: 0.8373 | g_loss: 0.6795
# Epoch [   30/   30] | d_loss: 0.7638 | g_loss: 0.8116
# Epoch [   30/   30] | d_loss: 0.7347 | g_loss: 0.8366
# Epoch [   30/   30] | d_loss: 0.8073 | g_loss: 0.5602
# Epoch [   30/   30] | d_loss: 0.6751 | g_loss: 0.8105
# Epoch [   30/   30] | d_loss: 0.8770 | g_loss: 0.6199
# /home/mina/anaconda3/lib/python3.7/site-packages/torch/storage.py:34: FutureWarning: pickle support for Storage will be removed in 1.5. Use `torch.save` instead
#   warnings.warn("pickle support for Storage will be removed in 1.5. Use `torch.save` instead", FutureWarning)

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:**
# * The pictures that are shown from the model have pixels on them. We could make them clearer.
# * We could improve the model by adding a bigger model size. Bigger models perform better results.
# * We could add more faces in our dataset and not only from famous people.
# * Increasing the number of epochs we could decrease the generator loss by giving better outputs.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
